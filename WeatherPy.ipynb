# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 597

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a4ea18b4a00efd159adc47ca2a30d51

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a4ea18b4a00efd159adc47ca2a30d51&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 12 | torbay
# Processing Record 2 of Set 12 | mataura
# Processing Record 3 of Set 12 | dzilam gonzalez
# Processing Record 4 of Set 12 | busselton
# Processing Record 5 of Set 12 | tasiilaq
# Processing Record 6 of Set 12 | hermanus
# Processing Record 7 of Set 12 | ribeira grande
# Processing Record 8 of Set 12 | alice springs
# Processing Record 9 of Set 12 | sidi ali
# Processing Record 10 of Set 12 | kuliyapitiya
# Processing Record 11 of Set 12 | lompoc
# Processing Record 12 of Set 12 | chernyshevskiy
# Processing Record 13 of Set 12 | brae
# Processing Record 14 of Set 12 | nemuro
# Processing Record 15 of Set 12 | avarua
# Processing Record 16 of Set 12 | toyooka
# Processing Record 17 of Set 12 | bluff
# Processing Record 18 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 19 of Set 12 | cabo san lucas
# Processing Record 20 of Set 12 | saskylakh
# Processing Record 21 of Set 12 | paarl
# Processing Record 22 of Set 12 | nikolskoye
# Processing Record 23 of Set 12 | luderitz
# Processing Record 24 of Set 12 | coos bay
# Processing Record 25 of Set 12 | bambanglipuro
# Processing Record 26 of Set 12 | sitka
# Processing Record 27 of Set 12 | vaini
# Processing Record 28 of Set 12 | carnarvon
# Processing Record 29 of Set 12 | bredasdorp
# Processing Record 30 of Set 12 | byron bay
# Processing Record 31 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 32 of Set 12 | rikitea
# Processing Record 33 of Set 12 | hokitika
# Processing Record 34 of Set 12 | asau
# Processing Record 35 of Set 12 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 12 | bandarbeyla
# Processing Record 37 of Set 12 | makaha
# Processing Record 38 of Set 12 | castro
# Processing Record 39 of Set 12 | bengkulu
# Processing Record 40 of Set 12 | moron
# Processing Record 41 of Set 12 | lata
# Processing Record 42 of Set 12 | castletown
# Processing Record 43 of Set 12 | cap-aux-meules
# Processing Record 44 of Set 12 | krasnoselkup
# Processing Record 45 of Set 12 | fort wellington
# Processing Record 46 of Set 12 | san patricio
# Processing Record 47 of Set 12 | punta arenas
# Processing Record 48 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 49 of Set 12 | rondonopolis
# Processing Record 50 of Set 12 | rinconada
# Processing Record 1 of Set 13 | sabzevar
# Processing Record 2 of Set 13 | cidreira
# Processing Record 3 of Set 13 | coihaique
# Processing Record 4 of Set 13 | atuona
# Processing Record 5 of Set 13 | cape town
# Processing Record 6 of Set 13 | barrow
# Processing Record 7 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 13 | georgetown
# Processing Record 9 of Set 13 | oranjestad
# Processing Record 10 of Set 13 | ushuaia
# Processing Record 11 of Set 13 | houston
# Processing Record 12 of Set 13 | sao filipe
# Processing Record 13 of Set 13 | kumla
# Processing Record 14 of Set 13 | port elizabeth
# Processing Record 15 of Set 13 | saint-philippe
# Processing Record 16 of Set 13 | teya
# Processing Record 17 of Set 13 | kroya
# Processing Record 18 of Set 13 | kadoma
# Processing Record 19 of Set 13 | fevralsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | poum
# Processing Record 21 of Set 13 | codrington
# Processing Record 22 of Set 13 | port hardy
# Processing Record 23 of Set 13 | pandamatenga
# Processing Record 24 of Set 13 | quatre cocos
# Processing Record 25 of Set 13 | qaanaaq
# Processing Record 26 of Set 13 | upernavik
# Processing Record 27 of Set 13 | vestmannaeyjar
# Processing Record 28 of Set 13 | ucluelet
# Processing Record 29 of Set 13 | gull lake
# Processing Record 30 of Set 13 | santander
# Processing Record 31 of Set 13 | neryungri
# Processing Record 32 of Set 13 | tuktoyaktuk
# Processing Record 33 of Set 13 | richards bay
# Processing Record 34 of Set 13 | necochea
# Processing Record 35 of Set 13 | petatlan
# Processing Record 36 of Set 13 | dikson
# Processing Record 37 of Set 13 | hobart
# Processing Record 38 of Set 13 | san carlos de bariloche
# Processing Record 39 of Set 13 | tuatapere
# Processing Record 40 of Set 13 | bilibino
# Processing Record 41 of Set 13 | valleyview
# Processing Record 42 of Set 13 | butaritari
# Processing Record 43 of Set 13 | chuy
# Processing Record 44 of Set 13 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 13 | chokurdakh
# Processing Record 46 of Set 13 | cockburn town
# Processing Record 47 of Set 13 | tocopilla
# Processing Record 48 of Set 13 | najran
# Processing Record 49 of Set 13 | hamilton
# Processing Record 50 of Set 13 | meulaboh
# Processing Record 1 of Set 14 | douentza
# Processing Record 2 of Set 14 | norman wells
# Processing Record 3 of Set 14 | leshukonskoye
# Processing Record 4 of Set 14 | mar del plata
# Processing Record 5 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 14 | ulverstone
# Processing Record 7 of Set 14 | eresos
# Processing Record 8 of Set 14 | labuhan
# Processing Record 9 of Set 14 | caravelas
# Processing Record 10 of Set 14 | lincoln
# Processing Record 11 of Set 14 | thompson
# Processing Record 12 of Set 14 | mikhaylovka
# Processing Record 13 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 14 | tisovec
# Processing Record 16 of Set 14 | narsaq
# Processing Record 17 of Set 14 | iqaluit
# Processing Record 18 of Set 14 | tiksi
# Processing Record 19 of Set 14 | puerto ayora
# Processing Record 20 of Set 14 | saint anthony
# Processing Record 21 of Set 14 | ponta do sol
# Processing Record 22 of Set 14 | albany
# Processing Record 23 of Set 14 | kavaratti
# Processing Record 24 of Set 14 | puerto pinasco
# City not found. Skipping...
# Processing Record 25 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 14 | taoudenni
# Processing Record 27 of Set 14 | santiago del estero
# Processing Record 28 of Set 14 | guerrero negro
# Processing Record 29 of Set 14 | port blair
# Processing Record 30 of Set 14 | saint-augustin
# Processing Record 31 of Set 14 | kaitangata
# Processing Record 32 of Set 14 | santa cruz
# Processing Record 33 of Set 14 | lebu
# Processing Record 34 of Set 14 | kapaa
# Processing Record 35 of Set 14 | ilulissat
# Processing Record 36 of Set 14 | yellowknife
# Processing Record 37 of Set 14 | bambous virieux
# Processing Record 38 of Set 14 | bay roberts
# Processing Record 39 of Set 14 | new norfolk
# Processing Record 40 of Set 14 | alofi
# Processing Record 41 of Set 14 | inhambane
# Processing Record 42 of Set 14 | kyren
# Processing Record 43 of Set 14 | naze
# Processing Record 44 of Set 14 | lorengau
# Processing Record 45 of Set 14 | cubuk
# Processing Record 46 of Set 14 | bridlington
# Processing Record 47 of Set 14 | tlaxiaco
# City not found. Skipping...
# Processing Record 48 of Set 14 | ngaoundere
# Processing Record 49 of Set 14 | general pico
# Processing Record 50 of Set 14 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 15 | port alfred
# Processing Record 2 of Set 15 | half moon bay
# Processing Record 3 of Set 15 | kupino
# Processing Record 4 of Set 15 | atasu
# Processing Record 5 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 15 | esperance
# Processing Record 7 of Set 15 | nukus
# Processing Record 8 of Set 15 | diego de almagro
# Processing Record 9 of Set 15 | jamestown
# Processing Record 10 of Set 15 | ostrovnoy
# Processing Record 11 of Set 15 | fort nelson
# Processing Record 12 of Set 15 | kloulklubed
# Processing Record 13 of Set 15 | clyde river
# Processing Record 14 of Set 15 | noumea
# Processing Record 15 of Set 15 | sabha
# Processing Record 16 of Set 15 | saint george
# Processing Record 17 of Set 15 | hilo
# Processing Record 18 of Set 15 | tigil
# Processing Record 19 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 15 | provideniya
# Processing Record 21 of Set 15 | camana
# Processing Record 22 of Set 15 | kapoeta
# Processing Record 23 of Set 15 | hithadhoo
# Processing Record 24 of Set 15 | anloga
# Processing Record 25 of Set 15 | touros
# Processing Record 26 of Set 15 | khatanga
# Processing Record 27 of Set 15 | mount isa
# Processing Record 28 of Set 15 | zhezkazgan
# Processing Record 29 of Set 15 | tilichiki
# Processing Record 30 of Set 15 | cap malheureux
# Processing Record 31 of Set 15 | jiazi
# Processing Record 32 of Set 15 | beira
# Processing Record 33 of Set 15 | cam pha
# City not found. Skipping...
# Processing Record 34 of Set 15 | urucara
# Processing Record 35 of Set 15 | coreau
# Processing Record 36 of Set 15 | flin flon
# Processing Record 37 of Set 15 | ano mera
# Processing Record 38 of Set 15 | seoni
# Processing Record 39 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 15 | jarjis
# City not found. Skipping...
# Processing Record 41 of Set 15 | wamba
# Processing Record 42 of Set 15 | airai
# Processing Record 43 of Set 15 | tyulgan
# Processing Record 44 of Set 15 | pemangkat
# Processing Record 45 of Set 15 | monrovia
# Processing Record 46 of Set 15 | melekhovskaya
# City not found. Skipping...
# Processing Record 47 of Set 15 | evensk
# Processing Record 48 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 15 | chara
# Processing Record 50 of Set 15 | alta floresta
# Processing Record 1 of Set 16 | fortuna
# Processing Record 2 of Set 16 | prieska
# Processing Record 3 of Set 16 | churapcha
# Processing Record 4 of Set 16 | coahuayana
# Processing Record 5 of Set 16 | tahta
# Processing Record 6 of Set 16 | ishigaki
# Processing Record 7 of Set 16 | wuwei
# Processing Record 8 of Set 16 | gornyak
# City not found. Skipping...
# Processing Record 9 of Set 16 | ginir
# Processing Record 10 of Set 16 | jalor
# Processing Record 11 of Set 16 | tura
# Processing Record 12 of Set 16 | geraldton
# Processing Record 13 of Set 16 | iskateley
# Processing Record 14 of Set 16 | dafeng
# Processing Record 15 of Set 16 | la peca
# Processing Record 16 of Set 16 | edd
# Processing Record 17 of Set 16 | codaesti
# Processing Record 18 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 16 | laguna
# Processing Record 20 of Set 16 | balakhta
# Processing Record 21 of Set 16 | andenes
# Processing Record 22 of Set 16 | east london
# Processing Record 23 of Set 16 | ceska ves
# Processing Record 24 of Set 16 | calama
# Processing Record 25 of Set 16 | jacareacanga
# Processing Record 26 of Set 16 | grafton
# Processing Record 27 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 16 | praia da vitoria
# Processing Record 29 of Set 16 | muros
# Processing Record 30 of Set 16 | north bend
# Processing Record 31 of Set 16 | tezu
# Processing Record 32 of Set 16 | nichinan
# Processing Record 33 of Set 16 | tazovskiy
# Processing Record 34 of Set 16 | arrecife
# Processing Record 35 of Set 16 | komsomolskiy
# Processing Record 36 of Set 16 | bubaque
# Processing Record 37 of Set 16 | hami
# Processing Record 38 of Set 16 | nagua
# Processing Record 39 of Set 16 | vypolzovo
# Processing Record 40 of Set 16 | lagoa
# Processing Record 41 of Set 16 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 16 | pisco
# Processing Record 43 of Set 16 | lavrentiya
# Processing Record 44 of Set 16 | puro
# Processing Record 45 of Set 16 | bethel
# Processing Record 46 of Set 16 | wiwili
# Processing Record 47 of Set 16 | weyburn
# Processing Record 48 of Set 16 | srandakan
# Processing Record 49 of Set 16 | nome
# Processing Record 50 of Set 16 | faanui
# Processing Record 1 of Set 17 | kudahuvadhoo
# Processing Record 2 of Set 17 | alexandria
# Processing Record 3 of Set 17 | kijang
# Processing Record 4 of Set 17 | nantucket
# Processing Record 5 of Set 17 | igrim
# Processing Record 6 of Set 17 | manyana
# Processing Record 7 of Set 17 | imbituba
# Processing Record 8 of Set 17 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 9 of Set 17 | anadyr
# Processing Record 10 of Set 17 | kuruman
# Processing Record 11 of Set 17 | haines junction
# Processing Record 12 of Set 17 | malkapur
# Processing Record 13 of Set 17 | port lincoln
# Processing Record 14 of Set 17 | pevek
# Processing Record 15 of Set 17 | nanortalik
# Processing Record 16 of Set 17 | rio gallegos
# Processing Record 17 of Set 17 | shar
# Processing Record 18 of Set 17 | mount gambier
# Processing Record 19 of Set 17 | dibrugarh
# Processing Record 20 of Set 17 | leningradskiy
# Processing Record 21 of Set 17 | mahibadhoo
# Processing Record 22 of Set 17 | ngama
# Processing Record 23 of Set 17 | katsuura
# Processing Record 24 of Set 17 | krusevac
# Processing Record 25 of Set 17 | prince george
# Processing Record 26 of Set 17 | san quintin
# Processing Record 27 of Set 17 | ahipara
# Processing Record 28 of Set 17 | kokuy
# Processing Record 29 of Set 17 | mehamn
# Processing Record 30 of Set 17 | komyshnya
# Processing Record 31 of Set 17 | mecca
# Processing Record 32 of Set 17 | tateyama
# Processing Record 33 of Set 17 | korla
# Processing Record 34 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 17 | makakilo city
# Processing Record 36 of Set 17 | belmonte
# Processing Record 37 of Set 17 | tapaua
# City not found. Skipping...
# Processing Record 38 of Set 17 | kahului
# Processing Record 39 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 17 | cayenne
# Processing Record 41 of Set 17 | camacha
# Processing Record 42 of Set 17 | kodiak
# Processing Record 43 of Set 17 | skoghall
# Processing Record 44 of Set 17 | flinders
# Processing Record 45 of Set 17 | constitucion
# Processing Record 46 of Set 17 | ancud
# Processing Record 47 of Set 17 | victoria
# Processing Record 48 of Set 17 | pallasovka
# Processing Record 49 of Set 17 | manokwari
# Processing Record 50 of Set 17 | marzuq
# Processing Record 1 of Set 18 | ust-uda
# Processing Record 2 of Set 18 | kathu
# Processing Record 3 of Set 18 | kiunga
# Processing Record 4 of Set 18 | boa vista
# Processing Record 5 of Set 18 | saryshagan
# City not found. Skipping...
# Processing Record 6 of Set 18 | the valley
# Processing Record 7 of Set 18 | talnakh
# Processing Record 8 of Set 18 | vejprty
# Processing Record 9 of Set 18 | voh
# Processing Record 10 of Set 18 | dagana
# Processing Record 11 of Set 18 | nouakchott
# Processing Record 12 of Set 18 | villa oliva
# City not found. Skipping...
# Processing Record 13 of Set 18 | souillac
# Processing Record 14 of Set 18 | abeche
# Processing Record 15 of Set 18 | mahebourg
# Processing Record 16 of Set 18 | borodino
# Processing Record 17 of Set 18 | kedrovyy
# Processing Record 18 of Set 18 | antigonish
# Processing Record 19 of Set 18 | zhuhai
# Processing Record 20 of Set 18 | bowen
# Processing Record 21 of Set 18 | bela vista de goias
# Processing Record 22 of Set 18 | srednekolymsk
# Processing Record 23 of Set 18 | cobija
# Processing Record 24 of Set 18 | aklavik
# Processing Record 25 of Set 18 | westport
# Processing Record 26 of Set 18 | patiya
# Processing Record 27 of Set 18 | marawi
# Processing Record 28 of Set 18 | benguela
# Processing Record 29 of Set 18 | berezovyy
# Processing Record 30 of Set 18 | palmer
# Processing Record 31 of Set 18 | hanzhong
# Processing Record 32 of Set 18 | balikpapan
# Processing Record 33 of Set 18 | tuy hoa
# Processing Record 34 of Set 18 | zlitan
# Processing Record 35 of Set 18 | dinsor
# City not found. Skipping...
# Processing Record 36 of Set 18 | aventura
# Processing Record 37 of Set 18 | namibe
# Processing Record 38 of Set 18 | galiwinku
# City not found. Skipping...
# Processing Record 39 of Set 18 | namatanai
# Processing Record 40 of Set 18 | pavlohrad
# Processing Record 41 of Set 18 | san andres
# Processing Record 42 of Set 18 | inuvik
# Processing Record 43 of Set 18 | acajutla
# Processing Record 44 of Set 18 | benxi
# Processing Record 45 of Set 18 | tecpan
# Processing Record 46 of Set 18 | puerto carreno
# Processing Record 47 of Set 18 | loei
# Processing Record 48 of Set 18 | mackay
# Processing Record 49 of Set 18 | sergeyevka
# Processing Record 50 of Set 18 | merauke
# Processing Record 1 of Set 19 | galgani
# City not found. Skipping...
# Processing Record 2 of Set 19 | gat
# Processing Record 3 of Set 19 | acapulco
# Processing Record 4 of Set 19 | mao
# Processing Record 5 of Set 19 | naples
# Processing Record 6 of Set 19 | price
# Processing Record 7 of Set 19 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 19 | waingapu
# Processing Record 9 of Set 19 | aksu
# Processing Record 10 of Set 19 | batagay-alyta
# Processing Record 11 of Set 19 | severo-kurilsk
# Processing Record 12 of Set 19 | saldanha
# Processing Record 13 of Set 19 | riverton
# Processing Record 14 of Set 19 | boda
# Processing Record 15 of Set 19 | kruisfontein
# Processing Record 16 of Set 19 | sistranda
# Processing Record 17 of Set 19 | poiana stampei
# Processing Record 18 of Set 19 | vardo
# Processing Record 19 of Set 19 | sao sebastiao
# Processing Record 20 of Set 19 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 19 | sarahan
# Processing Record 22 of Set 19 | tual
# Processing Record 23 of Set 19 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 19 | dhidhdhoo
# Processing Record 25 of Set 19 | cherskiy
# Processing Record 26 of Set 19 | ossora
# Processing Record 27 of Set 19 | arraial do cabo
# Processing Record 28 of Set 19 | concepcion
# Processing Record 29 of Set 19 | sola
# Processing Record 30 of Set 19 | medicine hat
# Processing Record 31 of Set 19 | aransas pass
# Processing Record 32 of Set 19 | kokopo
# Processing Record 33 of Set 19 | saint-georges
# Processing Record 34 of Set 19 | tabas
# Processing Record 35 of Set 19 | elko
# Processing Record 36 of Set 19 | semnan
# Processing Record 37 of Set 19 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 19 | aykhal
# Processing Record 39 of Set 19 | rafai
# Processing Record 40 of Set 19 | pangnirtung
# Processing Record 41 of Set 19 | boende
# Processing Record 42 of Set 19 | harindanga
# Processing Record 43 of Set 19 | maneadero
# Processing Record 44 of Set 19 | berlevag
# Processing Record 45 of Set 19 | almaznyy
# Processing Record 46 of Set 19 | palaiokhora
# City not found. Skipping...
# Processing Record 47 of Set 19 | santa isabel do rio negro
# Processing Record 48 of Set 19 | port keats
# Processing Record 49 of Set 19 | mashhad
# Processing Record 50 of Set 19 | lardos
# Processing Record 1 of Set 20 | amazar
# Processing Record 2 of Set 20 | joinville
# Processing Record 3 of Set 20 | solnechnyy
# Processing Record 4 of Set 20 | tatarbunary
# Processing Record 5 of Set 20 | mabaruma
# Processing Record 6 of Set 20 | gazojak
# Processing Record 7 of Set 20 | port-gentil
# Processing Record 8 of Set 20 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 20 | birao
# Processing Record 10 of Set 20 | nanyuki
# Processing Record 11 of Set 20 | mpanda
# Processing Record 12 of Set 20 | ijuin
# Processing Record 13 of Set 20 | bani
# Processing Record 14 of Set 20 | oreanda
# City not found. Skipping...
# Processing Record 15 of Set 20 | alugan
# Processing Record 16 of Set 20 | ballina
# Processing Record 17 of Set 20 | salalah
# Processing Record 18 of Set 20 | tautira
# Processing Record 19 of Set 20 | batticaloa
# Processing Record 20 of Set 20 | bokspits
# City not found. Skipping...
# Processing Record 21 of Set 20 | bendigo
# Processing Record 22 of Set 20 | henties bay
# Processing Record 23 of Set 20 | bayshore gardens
# Processing Record 24 of Set 20 | tabou
# Processing Record 25 of Set 20 | tara
# Processing Record 26 of Set 20 | wooster
# Processing Record 27 of Set 20 | obregon
# Processing Record 28 of Set 20 | telenesti
# Processing Record 29 of Set 20 | mount pleasant
# Processing Record 30 of Set 20 | elizabeth city
# Processing Record 31 of Set 20 | broome
# City not found. Skipping...
# Processing Record 32 of Set 20 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 20 | auki
# Processing Record 34 of Set 20 | poronaysk
# Processing Record 35 of Set 20 | baijiantan
# Processing Record 36 of Set 20 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 20 | pangody
# Processing Record 38 of Set 20 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 20 | rovaniemi
# Processing Record 40 of Set 20 | lasa
# Processing Record 41 of Set 20 | harwich
# Processing Record 42 of Set 20 | vanimo
# Processing Record 43 of Set 20 | sorong
# Processing Record 44 of Set 20 | westerland
# Processing Record 45 of Set 20 | sept-iles
# Processing Record 46 of Set 20 | high rock
# Processing Record 47 of Set 20 | stornoway
# Processing Record 48 of Set 20 | unye
# City not found. Skipping...
# Processing Record 49 of Set 20 | cabinda
# Processing Record 50 of Set 20 | hay river
# Processing Record 1 of Set 21 | northam
# Processing Record 2 of Set 21 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 21 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 21 | rock sound
# Processing Record 5 of Set 21 | inta
# Processing Record 6 of Set 21 | sibu
# Processing Record 7 of Set 21 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 8 of Set 21 | port hedland
# Processing Record 9 of Set 21 | arinos
# Processing Record 10 of Set 21 | ikalamavony
# Processing Record 11 of Set 21 | megion
# Processing Record 12 of Set 21 | klaksvik
# Processing Record 13 of Set 21 | aswan
# Processing Record 14 of Set 21 | freeport
# Processing Record 15 of Set 21 | duldurga
# Processing Record 16 of Set 21 | kathmandu
# Processing Record 17 of Set 21 | leninsk
# Processing Record 18 of Set 21 | mishelevka
# Processing Record 19 of Set 21 | labelle
# Processing Record 20 of Set 21 | maunabo
# Processing Record 21 of Set 21 | pandan
# Processing Record 22 of Set 21 | abu samrah
# Processing Record 23 of Set 21 | mocuba
# Processing Record 24 of Set 21 | saquena
# Processing Record 25 of Set 21 | xining
# Processing Record 26 of Set 21 | mayo
# Processing Record 27 of Set 21 | hofn
# Processing Record 28 of Set 21 | marshalltown
# Processing Record 29 of Set 21 | itarema
# Processing Record 30 of Set 21 | honiara
# Processing Record 31 of Set 21 | george
# Processing Record 32 of Set 21 | wloszczowa
# Processing Record 33 of Set 21 | texarkana
# Processing Record 34 of Set 21 | jackson
# Processing Record 35 of Set 21 | solovetskiy
# City not found. Skipping...
# Processing Record 36 of Set 21 | coquimbo
# Processing Record 37 of Set 21 | barraute
# Processing Record 38 of Set 21 | witu
# Processing Record 39 of Set 21 | sabang
# Processing Record 40 of Set 21 | ayan
# Processing Record 41 of Set 21 | horsham
# Processing Record 42 of Set 21 | portland
# Processing Record 43 of Set 21 | chifeng
# Processing Record 44 of Set 21 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 21 | burnie
# Processing Record 46 of Set 21 | corn island
# Processing Record 47 of Set 21 | biak
# Processing Record 48 of Set 21 | luebo
# Processing Record 49 of Set 21 | tunceli
# Processing Record 50 of Set 21 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 22 | marsa matruh
# Processing Record 2 of Set 22 | mednogorsk
# Processing Record 3 of Set 22 | antofagasta
# Processing Record 4 of Set 22 | zyryanka
# Processing Record 5 of Set 22 | ayagoz
# Processing Record 6 of Set 22 | podlesnoye
# Processing Record 7 of Set 22 | lima
# Processing Record 8 of Set 22 | tambopata
# Processing Record 9 of Set 22 | ulladulla
# Processing Record 10 of Set 22 | san cristobal
# Processing Record 11 of Set 22 | russell
# Processing Record 12 of Set 22 | husavik
# Processing Record 13 of Set 22 | anajatuba
# Processing Record 14 of Set 22 | svetlyy
# Processing Record 15 of Set 22 | boden
# Processing Record 16 of Set 22 | kutum
# Processing Record 17 of Set 22 | providencia
# Processing Record 18 of Set 22 | pilar
# Processing Record 19 of Set 22 | broken hill
# Processing Record 20 of Set 22 | sterling
# Processing Record 21 of Set 22 | yumen
# Processing Record 22 of Set 22 | rocha
# Processing Record 23 of Set 22 | dauphin
# Processing Record 24 of Set 22 | puerto escondido
# Processing Record 25 of Set 22 | shache
# Processing Record 26 of Set 22 | kyra
# Processing Record 27 of Set 22 | esso
# Processing Record 28 of Set 22 | warmbad
# Processing Record 29 of Set 22 | inyonga
# Processing Record 30 of Set 22 | kifri
# Processing Record 31 of Set 22 | bodden town
# Processing Record 32 of Set 22 | sardulgarh
# Processing Record 33 of Set 22 | lumphat
# Processing Record 34 of Set 22 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 22 | sinyavskoye
# Processing Record 36 of Set 22 | simpang
# Processing Record 37 of Set 22 | baykit
# Processing Record 38 of Set 22 | alacranes
# Processing Record 39 of Set 22 | vila velha
# Processing Record 40 of Set 22 | arman
# Processing Record 41 of Set 22 | cape elizabeth
# City not found. Skipping...
# Processing Record 42 of Set 22 | kologriv
# Processing Record 43 of Set 22 | bonoua
# Processing Record 44 of Set 22 | finnsnes
# Processing Record 45 of Set 22 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 22 | villeneuve-sur-lot
# Processing Record 47 of Set 22 | balimo
# City not found. Skipping...
# Processing Record 48 of Set 22 | umm durman
# City not found. Skipping...
# Processing Record 49 of Set 22 | george town
# Processing Record 50 of Set 22 | los llanos de aridane
# Processing Record 1 of Set 23 | kopyevo
# City not found. Skipping...
# Processing Record 2 of Set 23 | usinsk
# Processing Record 3 of Set 23 | balurghat
# Processing Record 4 of Set 23 | umm lajj
# Processing Record 5 of Set 23 | saint-raymond
# Processing Record 6 of Set 23 | ferme-neuve
# Processing Record 7 of Set 23 | beremend
# Processing Record 8 of Set 23 | segezha
# Processing Record 9 of Set 23 | alampur
# Processing Record 10 of Set 23 | uyuni
# Processing Record 11 of Set 23 | havelock
# Processing Record 12 of Set 23 | la huerta
# Processing Record 13 of Set 23 | umba
# Processing Record 14 of Set 23 | linhai
# Processing Record 15 of Set 23 | luchegorsk
# Processing Record 16 of Set 23 | vila franca do campo
# Processing Record 17 of Set 23 | addis zemen
# City not found. Skipping...
# Processing Record 18 of Set 23 | minna
# Processing Record 19 of Set 23 | grindavik
# Processing Record 20 of Set 23 | marsh harbour
# Processing Record 21 of Set 23 | ilan
# Processing Record 22 of Set 23 | uglovskoye
# Processing Record 23 of Set 23 | domoni
# Processing Record 24 of Set 23 | yar-sale
# Processing Record 25 of Set 23 | altay
# Processing Record 26 of Set 23 | maceio
# Processing Record 27 of Set 23 | mbeya
# Processing Record 28 of Set 23 | talcahuano
# Processing Record 29 of Set 23 | olinda
# Processing Record 30 of Set 23 | salinas
# Processing Record 31 of Set 23 | camopi
# Processing Record 32 of Set 23 | tubinskiy
# Processing Record 33 of Set 23 | eregli
# Processing Record 34 of Set 23 | severnyy
# Processing Record 35 of Set 23 | vila praia de ancora
# Processing Record 36 of Set 23 | kargasok
# Processing Record 37 of Set 23 | beloha
# Processing Record 38 of Set 23 | bria
# Processing Record 39 of Set 23 | nam tha
# City not found. Skipping...
# Processing Record 40 of Set 23 | yulara
# Processing Record 41 of Set 23 | pacific grove
# Processing Record 42 of Set 23 | te anau
# Processing Record 43 of Set 23 | hambantota
# Processing Record 44 of Set 23 | matagami
# Processing Record 45 of Set 23 | palana
# Processing Record 46 of Set 23 | bara
# Processing Record 47 of Set 23 | axim
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Torbay  47.67  -52.73     36.00        63          98        5.99
# 1          Mataura -46.19  168.86     57.00        95         100        3.58
# 2  Dzilam Gonzalez  21.28  -88.93     74.64        95          47        6.89
# 3        Busselton -33.65  115.33     70.00        35           0        6.69
# 4         Tasiilaq  65.61  -37.64     33.80        97          75        3.36
# 5         Hermanus -34.42   19.23     64.99        55          12        3.00
# 6   Ribeira Grande  38.52  -28.70     69.80        88          40       20.80
# 7    Alice Springs -23.70  133.88     68.00        14           4        5.82
# 8         Sidi Ali  36.10    0.42     74.97        33           0        4.88
# 9     Kuliyapitiya   7.47   80.04     80.87        75          73        3.22
#
#   Country                 Date
# 0      CA  2020-10-30 12:09:04
# 1      NZ  2020-10-30 12:09:04
# 2      MX  2020-10-30 12:09:05
# 3      AU  2020-10-30 12:09:06
# 4      GL  2020-10-30 12:09:07
# 5      ZA  2020-10-30 12:08:58
# 6      PT  2020-10-30 12:09:08
# 7      AU  2020-10-30 12:09:09
# 8      DZ  2020-10-30 12:09:10
# 9      LK  2020-10-30 12:09:11

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country                 Date    Lat     Lng  Max Temp  \
# 0             Torbay      CA  2020-10-30 12:09:04  47.67  -52.73     36.00
# 1            Mataura      NZ  2020-10-30 12:09:04 -46.19  168.86     57.00
# 2    Dzilam Gonzalez      MX  2020-10-30 12:09:05  21.28  -88.93     74.64
# 3          Busselton      AU  2020-10-30 12:09:06 -33.65  115.33     70.00
# 4           Tasiilaq      GL  2020-10-30 12:09:07  65.61  -37.64     33.80
# ..               ...     ...                  ...    ...     ...       ...
# 532       Hambantota      LK  2020-10-30 20:11:51   6.12   81.12     79.09
# 533         Matagami      CA  2020-10-30 20:11:52  49.75  -77.63     21.20
# 534           Palana      RU  2020-10-30 20:11:52  59.12  159.97     30.07
# 535             Bara      NG  2020-10-30 20:11:53  10.37   10.73     78.55
# 536             Axim      GH  2020-10-30 20:10:11   4.87   -2.24     78.69
#
#      Humidity  Cloudiness  Wind Speed
# 0          63          98        5.99
# 1          95         100        3.58
# 2          95          47        6.89
# 3          35           0        6.69
# 4          97          75        3.36
# ..        ...         ...         ...
# 532        80         100        9.84
# 533        67          20        8.05
# 534        97         100        5.68
# 535        33           0        2.86
# 536        84          91        4.21
#
# [537 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()

# %%
# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                       Nemuro
# Country                        JP
# Date          2020-10-30 12:07:31
# Lat                         43.32
# Lng                        145.57
# Max Temp                    49.78
# Humidity                       76
# Cloudiness                     61
# Wind Speed                  22.55
# Name: 13, dtype: object

# %%
city_data_df["Lat"] >= 0
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 532     True
# 533     True
# 534     True
# 535     True
# 536     True
# Name: Lat, Length: 537, dtype: bool

# %%
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#               City Country                 Date    Lat    Lng  Max Temp  \
# 0           Torbay      CA  2020-10-30 12:09:04  47.67 -52.73     36.00
# 2  Dzilam Gonzalez      MX  2020-10-30 12:09:05  21.28 -88.93     74.64
# 4         Tasiilaq      GL  2020-10-30 12:09:07  65.61 -37.64     33.80
# 6   Ribeira Grande      PT  2020-10-30 12:09:08  38.52 -28.70     69.80
# 8         Sidi Ali      DZ  2020-10-30 12:09:10  36.10   0.42     74.97
#
#    Humidity  Cloudiness  Wind Speed
# 0        63          98        5.99
# 2        95          47        6.89
# 4        97          75        3.36
# 6        88          40       20.80
# 8        33           0        4.88

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
from scipy.stats import linregress

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp',(10,40))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values, "Linear Regression on the Southern Hemisphere \n for Maximum Temperature", 'Max Temp',(-50,90))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \nfor % Humidity', '% Humidity',(40,10))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \nfor % Humidity', '% Humidity',(-50,15))

# %%
# Linear regression on the Southern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       'Linear Regression on the Northern Hemisphere \nfor % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-50,60))

# %%
# Linear regression on the Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed',(40,35))

# %%
# Linear regression on the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values,
                       'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed',(-50,35))

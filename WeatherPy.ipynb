# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 598

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a4ea18b4a00efd159adc47ca2a30d51

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a4ea18b4a00efd159adc47ca2a30d51&q=Boston

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 12 | bethel
# Processing Record 2 of Set 12 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 12 | hobart
# Processing Record 4 of Set 12 | meadow lake
# Processing Record 5 of Set 12 | bluff
# Processing Record 6 of Set 12 | saldanha
# Processing Record 7 of Set 12 | vostok
# Processing Record 8 of Set 12 | nioro
# Processing Record 9 of Set 12 | cherskiy
# Processing Record 10 of Set 12 | yellowknife
# Processing Record 11 of Set 12 | mataura
# Processing Record 12 of Set 12 | kodiak
# Processing Record 13 of Set 12 | rikitea
# Processing Record 14 of Set 12 | punta arenas
# Processing Record 15 of Set 12 | uyemskiy
# Processing Record 16 of Set 12 | port alfred
# Processing Record 17 of Set 12 | bambous virieux
# Processing Record 18 of Set 12 | cayenne
# Processing Record 19 of Set 12 | ushuaia
# Processing Record 20 of Set 12 | egvekinot
# Processing Record 21 of Set 12 | puerto ayora
# Processing Record 22 of Set 12 | pevek
# Processing Record 23 of Set 12 | hermanus
# Processing Record 24 of Set 12 | la ronge
# Processing Record 25 of Set 12 | buraydah
# Processing Record 26 of Set 12 | esperance
# Processing Record 27 of Set 12 | victoria
# Processing Record 28 of Set 12 | celldomolk
# Processing Record 29 of Set 12 | dragoman
# Processing Record 30 of Set 12 | varlamovo
# Processing Record 31 of Set 12 | constitucion
# Processing Record 32 of Set 12 | thinadhoo
# Processing Record 33 of Set 12 | yambio
# Processing Record 34 of Set 12 | castro
# Processing Record 35 of Set 12 | nikolskoye
# Processing Record 36 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 12 | dudinka
# Processing Record 38 of Set 12 | saskylakh
# Processing Record 39 of Set 12 | sitka
# Processing Record 40 of Set 12 | asfi
# Processing Record 41 of Set 12 | yerbogachen
# Processing Record 42 of Set 12 | pasighat
# Processing Record 43 of Set 12 | monte carmelo
# Processing Record 44 of Set 12 | cape town
# Processing Record 45 of Set 12 | mbanza-ngungu
# Processing Record 46 of Set 12 | kavieng
# Processing Record 47 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 12 | kapaa
# Processing Record 49 of Set 12 | tiznit
# Processing Record 50 of Set 12 | port blair
# Processing Record 1 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 13 | olafsvik
# Processing Record 3 of Set 13 | valparaiso
# Processing Record 4 of Set 13 | albany
# Processing Record 5 of Set 13 | tiksi
# Processing Record 6 of Set 13 | douentza
# Processing Record 7 of Set 13 | west wendover
# Processing Record 8 of Set 13 | tuktoyaktuk
# Processing Record 9 of Set 13 | tasiilaq
# Processing Record 10 of Set 13 | mabaruma
# Processing Record 11 of Set 13 | vaini
# Processing Record 12 of Set 13 | hilo
# Processing Record 13 of Set 13 | aktau
# Processing Record 14 of Set 13 | zalantun
# Processing Record 15 of Set 13 | mut
# Processing Record 16 of Set 13 | terney
# Processing Record 17 of Set 13 | carnarvon
# Processing Record 18 of Set 13 | severo-kurilsk
# Processing Record 19 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 20 of Set 13 | hailey
# Processing Record 21 of Set 13 | blagoyevo
# Processing Record 22 of Set 13 | faanui
# Processing Record 23 of Set 13 | caravelas
# Processing Record 24 of Set 13 | cabo san lucas
# Processing Record 25 of Set 13 | kavaratti
# Processing Record 26 of Set 13 | dunedin
# Processing Record 27 of Set 13 | barrow
# Processing Record 28 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 13 | thompson
# Processing Record 30 of Set 13 | waipawa
# Processing Record 31 of Set 13 | busselton
# Processing Record 32 of Set 13 | leningradskiy
# Processing Record 33 of Set 13 | sao joao da barra
# Processing Record 34 of Set 13 | camocim
# Processing Record 35 of Set 13 | hofn
# Processing Record 36 of Set 13 | kalmunai
# Processing Record 37 of Set 13 | alofi
# Processing Record 38 of Set 13 | bengkulu
# Processing Record 39 of Set 13 | ranau
# Processing Record 40 of Set 13 | toungoo
# City not found. Skipping...
# Processing Record 41 of Set 13 | jalu
# Processing Record 42 of Set 13 | linxi
# Processing Record 43 of Set 13 | serpa
# Processing Record 44 of Set 13 | voh
# Processing Record 45 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 13 | yerofey pavlovich
# Processing Record 47 of Set 13 | pangai
# Processing Record 48 of Set 13 | chifeng
# Processing Record 49 of Set 13 | sao bento
# Processing Record 50 of Set 13 | saint george
# Processing Record 1 of Set 14 | itaqui
# Processing Record 2 of Set 14 | saint anthony
# Processing Record 3 of Set 14 | kismayo
# Processing Record 4 of Set 14 | sindand
# City not found. Skipping...
# Processing Record 5 of Set 14 | cidreira
# Processing Record 6 of Set 14 | atuona
# Processing Record 7 of Set 14 | polewali
# Processing Record 8 of Set 14 | kampong chhnang
# Processing Record 9 of Set 14 | tonantins
# Processing Record 10 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 14 | east london
# Processing Record 12 of Set 14 | nome
# Processing Record 13 of Set 14 | touros
# Processing Record 14 of Set 14 | butaritari
# Processing Record 15 of Set 14 | kuah
# Processing Record 16 of Set 14 | novyy urgal
# Processing Record 17 of Set 14 | magadan
# Processing Record 18 of Set 14 | la paz
# Processing Record 19 of Set 14 | ozernovskiy
# Processing Record 20 of Set 14 | tessalit
# Processing Record 21 of Set 14 | porto walter
# Processing Record 22 of Set 14 | tateyama
# Processing Record 23 of Set 14 | narsaq
# Processing Record 24 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 14 | yertarskiy
# Processing Record 26 of Set 14 | salalah
# Processing Record 27 of Set 14 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 14 | bourail
# Processing Record 29 of Set 14 | stuttgart
# Processing Record 30 of Set 14 | jaguarao
# Processing Record 31 of Set 14 | georgetown
# Processing Record 32 of Set 14 | lilongwe
# Processing Record 33 of Set 14 | qaanaaq
# Processing Record 34 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 35 of Set 14 | jamestown
# Processing Record 36 of Set 14 | hami
# Processing Record 37 of Set 14 | iqaluit
# Processing Record 38 of Set 14 | mahebourg
# Processing Record 39 of Set 14 | zapolyarnyy
# Processing Record 40 of Set 14 | san policarpo
# Processing Record 41 of Set 14 | sao filipe
# Processing Record 42 of Set 14 | north bend
# Processing Record 43 of Set 14 | la rioja
# Processing Record 44 of Set 14 | akyab
# Processing Record 45 of Set 14 | klaksvik
# Processing Record 46 of Set 14 | khatanga
# Processing Record 47 of Set 14 | palmer
# Processing Record 48 of Set 14 | port hardy
# Processing Record 49 of Set 14 | dikson
# Processing Record 50 of Set 14 | sinnamary
# Processing Record 1 of Set 15 | shimoda
# Processing Record 2 of Set 15 | asau
# Processing Record 3 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 4 of Set 15 | vila velha
# Processing Record 5 of Set 15 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 15 | sabang
# Processing Record 7 of Set 15 | halifax
# Processing Record 8 of Set 15 | cerasu
# Processing Record 9 of Set 15 | fairbanks
# Processing Record 10 of Set 15 | kamenka
# Processing Record 11 of Set 15 | lubango
# Processing Record 12 of Set 15 | deer lake
# Processing Record 13 of Set 15 | gizo
# Processing Record 14 of Set 15 | namatanai
# Processing Record 15 of Set 15 | tilichiki
# Processing Record 16 of Set 15 | druzhba
# Processing Record 17 of Set 15 | ibra
# Processing Record 18 of Set 15 | lorengau
# Processing Record 19 of Set 15 | toulepleu
# City not found. Skipping...
# Processing Record 20 of Set 15 | gilgit
# Processing Record 21 of Set 15 | tutoia
# Processing Record 22 of Set 15 | hasaki
# Processing Record 23 of Set 15 | saint-philippe
# Processing Record 24 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 26 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 15 | san luis
# Processing Record 28 of Set 15 | paracuru
# Processing Record 29 of Set 15 | moosomin
# Processing Record 30 of Set 15 | kindu
# Processing Record 31 of Set 15 | mar del plata
# Processing Record 32 of Set 15 | palauig
# Processing Record 33 of Set 15 | porto santo
# Processing Record 34 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 15 | nata
# Processing Record 36 of Set 15 | jumla
# Processing Record 37 of Set 15 | sakakah
# Processing Record 38 of Set 15 | naze
# Processing Record 39 of Set 15 | avarua
# Processing Record 40 of Set 15 | kruisfontein
# Processing Record 41 of Set 15 | clyde river
# Processing Record 42 of Set 15 | chuy
# Processing Record 43 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 15 | dzhida
# Processing Record 45 of Set 15 | karasjok
# Processing Record 46 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 15 | fortuna
# Processing Record 48 of Set 15 | te anau
# Processing Record 49 of Set 15 | chapleau
# Processing Record 50 of Set 15 | baoding
# Processing Record 1 of Set 16 | chapais
# Processing Record 2 of Set 16 | harper
# Processing Record 3 of Set 16 | lakheri
# Processing Record 4 of Set 16 | taos
# Processing Record 5 of Set 16 | clovis
# Processing Record 6 of Set 16 | hambantota
# Processing Record 7 of Set 16 | port elizabeth
# Processing Record 8 of Set 16 | bam
# Processing Record 9 of Set 16 | tacuati
# Processing Record 10 of Set 16 | ribeira grande
# Processing Record 11 of Set 16 | pacific grove
# Processing Record 12 of Set 16 | sao gabriel da cachoeira
# Processing Record 13 of Set 16 | lincoln
# Processing Record 14 of Set 16 | tuatapere
# Processing Record 15 of Set 16 | oussouye
# Processing Record 16 of Set 16 | chokurdakh
# Processing Record 17 of Set 16 | puerto escondido
# Processing Record 18 of Set 16 | singaraja
# Processing Record 19 of Set 16 | bouillante
# Processing Record 20 of Set 16 | harlingen
# Processing Record 21 of Set 16 | sentyabrskiy
# City not found. Skipping...
# Processing Record 22 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 16 | lagoa
# Processing Record 24 of Set 16 | alice springs
# Processing Record 25 of Set 16 | vila franca do campo
# Processing Record 26 of Set 16 | port lincoln
# Processing Record 27 of Set 16 | kenai
# Processing Record 28 of Set 16 | tautira
# Processing Record 29 of Set 16 | guerrero negro
# Processing Record 30 of Set 16 | arraial do cabo
# Processing Record 31 of Set 16 | mayo
# Processing Record 32 of Set 16 | strezhevoy
# Processing Record 33 of Set 16 | saint-pierre
# Processing Record 34 of Set 16 | tallahassee
# Processing Record 35 of Set 16 | shahreza
# Processing Record 36 of Set 16 | natal
# Processing Record 37 of Set 16 | rudbar
# Processing Record 38 of Set 16 | punta alta
# Processing Record 39 of Set 16 | clarksburg
# Processing Record 40 of Set 16 | sataua
# City not found. Skipping...
# Processing Record 41 of Set 16 | new norfolk
# Processing Record 42 of Set 16 | comodoro rivadavia
# Processing Record 43 of Set 16 | kaitangata
# Processing Record 44 of Set 16 | macapa
# Processing Record 45 of Set 16 | samarai
# Processing Record 46 of Set 16 | codrington
# Processing Record 47 of Set 16 | wanaka
# Processing Record 48 of Set 16 | makrikapa
# City not found. Skipping...
# Processing Record 49 of Set 16 | turukhansk
# Processing Record 50 of Set 16 | padang
# Processing Record 1 of Set 17 | krasnoselkup
# Processing Record 2 of Set 17 | waingapu
# Processing Record 3 of Set 17 | vavoua
# Processing Record 4 of Set 17 | luderitz
# Processing Record 5 of Set 17 | namibe
# Processing Record 6 of Set 17 | cascais
# Processing Record 7 of Set 17 | nicoya
# Processing Record 8 of Set 17 | mayenne
# Processing Record 9 of Set 17 | najran
# Processing Record 10 of Set 17 | algeciras
# Processing Record 11 of Set 17 | san cristobal
# Processing Record 12 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 17 | hithadhoo
# Processing Record 14 of Set 17 | yumen
# Processing Record 15 of Set 17 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 17 | jieshi
# Processing Record 17 of Set 17 | taoudenni
# Processing Record 18 of Set 17 | chornyanka
# Processing Record 19 of Set 17 | meulaboh
# Processing Record 20 of Set 17 | shakhrinau
# City not found. Skipping...
# Processing Record 21 of Set 17 | barcelos
# Processing Record 22 of Set 17 | iquique
# Processing Record 23 of Set 17 | zachagansk
# City not found. Skipping...
# Processing Record 24 of Set 17 | kyshtovka
# Processing Record 25 of Set 17 | jablah
# Processing Record 26 of Set 17 | skjervoy
# Processing Record 27 of Set 17 | neuquen
# Processing Record 28 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 17 | nanortalik
# Processing Record 30 of Set 17 | kahului
# Processing Record 31 of Set 17 | winneba
# Processing Record 32 of Set 17 | broken hill
# Processing Record 33 of Set 17 | torbay
# Processing Record 34 of Set 17 | baykit
# Processing Record 35 of Set 17 | bubaque
# Processing Record 36 of Set 17 | presidencia roque saenz pena
# Processing Record 37 of Set 17 | westport
# Processing Record 38 of Set 17 | pisco
# Processing Record 39 of Set 17 | mao
# Processing Record 40 of Set 17 | souillac
# Processing Record 41 of Set 17 | san quintin
# Processing Record 42 of Set 17 | necochea
# Processing Record 43 of Set 17 | guicheng
# City not found. Skipping...
# Processing Record 44 of Set 17 | provideniya
# Processing Record 45 of Set 17 | pandrup
# Processing Record 46 of Set 17 | russell
# Processing Record 47 of Set 17 | rongcheng
# Processing Record 48 of Set 17 | garowe
# Processing Record 49 of Set 17 | kattivakkam
# Processing Record 50 of Set 17 | khani
# Processing Record 1 of Set 18 | buala
# Processing Record 2 of Set 18 | mosalsk
# Processing Record 3 of Set 18 | biloela
# Processing Record 4 of Set 18 | dakar
# Processing Record 5 of Set 18 | jabiru
# City not found. Skipping...
# Processing Record 6 of Set 18 | labuhan
# Processing Record 7 of Set 18 | shingu
# Processing Record 8 of Set 18 | coxquihui
# Processing Record 9 of Set 18 | kaeo
# Processing Record 10 of Set 18 | laguna
# Processing Record 11 of Set 18 | valley station
# Processing Record 12 of Set 18 | progreso
# Processing Record 13 of Set 18 | dharchula
# Processing Record 14 of Set 18 | upernavik
# Processing Record 15 of Set 18 | minot
# Processing Record 16 of Set 18 | mehamn
# Processing Record 17 of Set 18 | high level
# Processing Record 18 of Set 18 | airai
# Processing Record 19 of Set 18 | hualmay
# Processing Record 20 of Set 18 | perumpavur
# Processing Record 21 of Set 18 | bredasdorp
# Processing Record 22 of Set 18 | zhezkazgan
# Processing Record 23 of Set 18 | aykhal
# Processing Record 24 of Set 18 | fare
# Processing Record 25 of Set 18 | mayumba
# Processing Record 26 of Set 18 | steinbach
# Processing Record 27 of Set 18 | chokwe
# Processing Record 28 of Set 18 | pocone
# Processing Record 29 of Set 18 | mogwase
# Processing Record 30 of Set 18 | mykolayivka
# Processing Record 31 of Set 18 | marquette
# Processing Record 32 of Set 18 | arman
# Processing Record 33 of Set 18 | beringovskiy
# Processing Record 34 of Set 18 | henties bay
# Processing Record 35 of Set 18 | khowst
# Processing Record 36 of Set 18 | corowa
# Processing Record 37 of Set 18 | bela
# Processing Record 38 of Set 18 | evensk
# Processing Record 39 of Set 18 | sur
# Processing Record 40 of Set 18 | hargeysa
# Processing Record 41 of Set 18 | gat
# Processing Record 42 of Set 18 | matay
# Processing Record 43 of Set 18 | anadyr
# Processing Record 44 of Set 18 | noumea
# Processing Record 45 of Set 18 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 18 | pogradec
# Processing Record 47 of Set 18 | cedral
# Processing Record 48 of Set 18 | ilulissat
# Processing Record 49 of Set 18 | itigi
# Processing Record 50 of Set 18 | isangel
# Processing Record 1 of Set 19 | puerto del rosario
# Processing Record 2 of Set 19 | katsuura
# Processing Record 3 of Set 19 | dingle
# Processing Record 4 of Set 19 | kimbe
# Processing Record 5 of Set 19 | deputatskiy
# Processing Record 6 of Set 19 | marv dasht
# City not found. Skipping...
# Processing Record 7 of Set 19 | avera
# Processing Record 8 of Set 19 | wenling
# Processing Record 9 of Set 19 | robertsport
# Processing Record 10 of Set 19 | tancanhuitz
# Processing Record 11 of Set 19 | husavik
# Processing Record 12 of Set 19 | zhigansk
# Processing Record 13 of Set 19 | muros
# Processing Record 14 of Set 19 | nemuro
# Processing Record 15 of Set 19 | mishan
# Processing Record 16 of Set 19 | eyrarbakki
# Processing Record 17 of Set 19 | arcata
# Processing Record 18 of Set 19 | ponta do sol
# Processing Record 19 of Set 19 | alugan
# Processing Record 20 of Set 19 | gari
# Processing Record 21 of Set 19 | hagen
# Processing Record 22 of Set 19 | zabol
# Processing Record 23 of Set 19 | bassano
# Processing Record 24 of Set 19 | tselinnoye
# Processing Record 25 of Set 19 | simao
# Processing Record 26 of Set 19 | verkhoyansk
# Processing Record 27 of Set 19 | komsomolskiy
# Processing Record 28 of Set 19 | vardo
# Processing Record 29 of Set 19 | awbari
# Processing Record 30 of Set 19 | la ferte-bernard
# Processing Record 31 of Set 19 | paita
# Processing Record 32 of Set 19 | northam
# Processing Record 33 of Set 19 | grindavik
# Processing Record 34 of Set 19 | banepa
# Processing Record 35 of Set 19 | teahupoo
# Processing Record 36 of Set 19 | kloulklubed
# Processing Record 37 of Set 19 | yaan
# Processing Record 38 of Set 19 | pervomayskaya
# Processing Record 39 of Set 19 | boralday
# Processing Record 40 of Set 19 | paamiut
# Processing Record 41 of Set 19 | dongying
# Processing Record 42 of Set 19 | saint-georges
# Processing Record 43 of Set 19 | longyan
# Processing Record 44 of Set 19 | mount isa
# Processing Record 45 of Set 19 | andenes
# Processing Record 46 of Set 19 | avigliano
# Processing Record 47 of Set 19 | rujewa
# Processing Record 48 of Set 19 | plettenberg bay
# Processing Record 49 of Set 19 | ratodero
# Processing Record 50 of Set 19 | lebu
# Processing Record 1 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 20 | mattru
# Processing Record 3 of Set 20 | mount gambier
# Processing Record 4 of Set 20 | magadi
# Processing Record 5 of Set 20 | beira
# Processing Record 6 of Set 20 | agadez
# Processing Record 7 of Set 20 | santa fe
# Processing Record 8 of Set 20 | sandakan
# Processing Record 9 of Set 20 | camacha
# Processing Record 10 of Set 20 | grand-lahou
# Processing Record 11 of Set 20 | manzhouli
# Processing Record 12 of Set 20 | batemans bay
# Processing Record 13 of Set 20 | kokopo
# Processing Record 14 of Set 20 | ust-maya
# Processing Record 15 of Set 20 | olavarria
# Processing Record 16 of Set 20 | belmopan
# Processing Record 17 of Set 20 | den helder
# Processing Record 18 of Set 20 | brasileia
# Processing Record 19 of Set 20 | shiliguri
# Processing Record 20 of Set 20 | eyl
# Processing Record 21 of Set 20 | alta floresta
# Processing Record 22 of Set 20 | tura
# Processing Record 23 of Set 20 | bardiyah
# Processing Record 24 of Set 20 | besancon
# Processing Record 25 of Set 20 | ossora
# Processing Record 26 of Set 20 | sachin
# Processing Record 27 of Set 20 | haapiti
# Processing Record 28 of Set 20 | acari
# Processing Record 29 of Set 20 | sao felix do xingu
# Processing Record 30 of Set 20 | sorong
# Processing Record 31 of Set 20 | ereymentau
# Processing Record 32 of Set 20 | porbandar
# Processing Record 33 of Set 20 | mabiton
# Processing Record 34 of Set 20 | teguise
# Processing Record 35 of Set 20 | kaliyaganj
# Processing Record 36 of Set 20 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 20 | shubarshi
# Processing Record 38 of Set 20 | upata
# Processing Record 39 of Set 20 | pedernales
# Processing Record 40 of Set 20 | cururupu
# Processing Record 41 of Set 20 | burnie
# Processing Record 42 of Set 20 | el badari
# City not found. Skipping...
# Processing Record 43 of Set 20 | viedma
# Processing Record 44 of Set 20 | biak
# Processing Record 45 of Set 20 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 20 | kurilsk
# Processing Record 47 of Set 20 | bathsheba
# Processing Record 48 of Set 20 | longyearbyen
# Processing Record 49 of Set 20 | west fargo
# Processing Record 50 of Set 20 | hay river
# Processing Record 1 of Set 21 | republic
# Processing Record 2 of Set 21 | ketchikan
# Processing Record 3 of Set 21 | thunder bay
# Processing Record 4 of Set 21 | angatuba
# Processing Record 5 of Set 21 | brandon
# Processing Record 6 of Set 21 | taltal
# Processing Record 7 of Set 21 | hervey bay
# Processing Record 8 of Set 21 | ayorou
# Processing Record 9 of Set 21 | conceicao do araguaia
# Processing Record 10 of Set 21 | auki
# Processing Record 11 of Set 21 | skegness
# Processing Record 12 of Set 21 | hecun
# Processing Record 13 of Set 21 | xuddur
# Processing Record 14 of Set 21 | huron
# Processing Record 15 of Set 21 | manokwari
# Processing Record 16 of Set 21 | karera
# Processing Record 17 of Set 21 | revda
# Processing Record 18 of Set 21 | portland
# Processing Record 19 of Set 21 | margate
# Processing Record 20 of Set 21 | luba
# Processing Record 21 of Set 21 | dwarka
# Processing Record 22 of Set 21 | maloy
# Processing Record 23 of Set 21 | praia
# Processing Record 24 of Set 21 | havre-saint-pierre
# Processing Record 25 of Set 21 | omboue
# Processing Record 26 of Set 21 | burla
# Processing Record 27 of Set 21 | shahr-e kord
# Processing Record 28 of Set 21 | severnyy
# Processing Record 29 of Set 21 | lavrentiya
# Processing Record 30 of Set 21 | oktyabrskiy
# Processing Record 31 of Set 21 | katha
# City not found. Skipping...
# Processing Record 32 of Set 21 | kiunga
# Processing Record 33 of Set 21 | raudeberg
# Processing Record 34 of Set 21 | cairns
# Processing Record 35 of Set 21 | fukue
# Processing Record 36 of Set 21 | maralal
# Processing Record 37 of Set 21 | aginskoye
# Processing Record 38 of Set 21 | ostrovnoy
# Processing Record 39 of Set 21 | gotsu
# Processing Record 40 of Set 21 | lompoc
# Processing Record 41 of Set 21 | havoysund
# Processing Record 42 of Set 21 | masallatah
# Processing Record 43 of Set 21 | ishigaki
# Processing Record 44 of Set 21 | megion
# Processing Record 45 of Set 21 | rundu
# Processing Record 46 of Set 21 | ipora
# Processing Record 47 of Set 21 | kachiry
# Processing Record 48 of Set 21 | pandan
# Processing Record 49 of Set 21 | qasigiannguit
# Processing Record 50 of Set 21 | kings mountain
# Processing Record 1 of Set 22 | bandarbeyla
# Processing Record 2 of Set 22 | aquiraz
# Processing Record 3 of Set 22 | galiwinku
# City not found. Skipping...
# Processing Record 4 of Set 22 | makakilo city
# Processing Record 5 of Set 22 | trincomalee
# Processing Record 6 of Set 22 | rio grande
# Processing Record 7 of Set 22 | garden city
# Processing Record 8 of Set 22 | aflu
# City not found. Skipping...
# Processing Record 9 of Set 22 | mangan
# Processing Record 10 of Set 22 | bonthe
# Processing Record 11 of Set 22 | port-gentil
# Processing Record 12 of Set 22 | manchester
# Processing Record 13 of Set 22 | coihaique
# Processing Record 14 of Set 22 | oranjestad
# Processing Record 15 of Set 22 | adrar
# Processing Record 16 of Set 22 | nexo
# Processing Record 17 of Set 22 | gamba
# Processing Record 18 of Set 22 | mikkeli
# Processing Record 19 of Set 22 | kolondieba
# Processing Record 20 of Set 22 | meybod
# Processing Record 21 of Set 22 | champerico
# Processing Record 22 of Set 22 | chimbote
# Processing Record 23 of Set 22 | isabela
# Processing Record 24 of Set 22 | manta
# Processing Record 25 of Set 22 | tukrah
# Processing Record 26 of Set 22 | honiara
# Processing Record 27 of Set 22 | fernie
# Processing Record 28 of Set 22 | monrovia
# Processing Record 29 of Set 22 | flinders
# Processing Record 30 of Set 22 | sakaraha
# Processing Record 31 of Set 22 | negele
# City not found. Skipping...
# Processing Record 32 of Set 22 | cortland
# Processing Record 33 of Set 22 | norman wells
# Processing Record 34 of Set 22 | banda aceh
# Processing Record 35 of Set 22 | shemysheyka
# Processing Record 36 of Set 22 | stamsund
# City not found. Skipping...
# Processing Record 37 of Set 22 | chicama
# Processing Record 38 of Set 22 | sarishabari
# Processing Record 39 of Set 22 | porto nacional
# Processing Record 40 of Set 22 | wuchang
# Processing Record 41 of Set 22 | raga
# Processing Record 42 of Set 22 | lujan
# Processing Record 43 of Set 22 | encruzilhada
# Processing Record 44 of Set 22 | shahr-e babak
# Processing Record 45 of Set 22 | chantilly
# Processing Record 46 of Set 22 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 22 | ancud
# Processing Record 48 of Set 22 | byron bay
# Processing Record 49 of Set 22 | yulara
# Processing Record 50 of Set 22 | lata
# Processing Record 1 of Set 23 | talnakh
# Processing Record 2 of Set 23 | hobyo
# Processing Record 3 of Set 23 | odessa
# Processing Record 4 of Set 23 | masterton
# Processing Record 5 of Set 23 | udachnyy
# Processing Record 6 of Set 23 | la orilla
# Processing Record 7 of Set 23 | lokoja
# Processing Record 8 of Set 23 | hanko
# Processing Record 9 of Set 23 | quixeramobim
# Processing Record 10 of Set 23 | tagusao
# Processing Record 11 of Set 23 | tarasovskiy
# Processing Record 12 of Set 23 | okato
# Processing Record 13 of Set 23 | ola
# Processing Record 14 of Set 23 | diego de almagro
# Processing Record 15 of Set 23 | sabha
# Processing Record 16 of Set 23 | aviles
# Processing Record 17 of Set 23 | one hundred mile house
# City not found. Skipping...
# Processing Record 18 of Set 23 | prince rupert
# Processing Record 19 of Set 23 | assiniboia
# Processing Record 20 of Set 23 | marzuq
# Processing Record 21 of Set 23 | ouallam
# Processing Record 22 of Set 23 | belmonte
# Processing Record 23 of Set 23 | oksfjord
# Processing Record 24 of Set 23 | sibenik
# Processing Record 25 of Set 23 | xiamen
# Processing Record 26 of Set 23 | sharjah
# Processing Record 27 of Set 23 | tecpan
# Processing Record 28 of Set 23 | yakeshi
# Processing Record 29 of Set 23 | geraldton
# Processing Record 30 of Set 23 | panaba
# Processing Record 31 of Set 23 | roald
# Processing Record 32 of Set 23 | alekseyevskaya
# Processing Record 33 of Set 23 | gornyy
# Processing Record 34 of Set 23 | usinsk
# Processing Record 35 of Set 23 | chirongui
# Processing Record 36 of Set 23 | kalemie
# Processing Record 37 of Set 23 | gimli
# Processing Record 38 of Set 23 | belaya gora
# Processing Record 39 of Set 23 | lumphat
# Processing Record 40 of Set 23 | port macquarie
# Processing Record 41 of Set 23 | hvittingfoss
# Processing Record 42 of Set 23 | debre sina
# Processing Record 43 of Set 23 | nhulunbuy
# Processing Record 44 of Set 23 | fort nelson
# Processing Record 45 of Set 23 | kabinda
# Processing Record 46 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 23 | moose factory
# Processing Record 48 of Set 23 | poronaysk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bethel  41.37  -73.41     48.00        93           1        2.68
# 1       Hobart -42.88  147.33     62.60        42          40       13.87
# 2  Meadow Lake  34.80 -106.54     37.40        74           1        3.36
# 3        Bluff -46.60  168.33     62.01        71          40        3.00
# 4     Saldanha -33.01   17.94     59.00        87          56        3.36
# 5       Vostok  46.49  135.88     29.17       100         100       11.70
# 6        Nioro  13.35  -15.75     74.43        63          46        3.80
# 7     Cherskiy  68.75  161.30      4.71        93          76        3.49
# 8  Yellowknife  62.46 -114.35     17.60        92          75       12.75
# 9      Mataura -46.19  168.86     62.01        71          20        3.00
#
#   Country                 Date
# 0      US  2020-10-29 06:01:38
# 1      AU  2020-10-29 05:57:48
# 2      US  2020-10-29 05:56:44
# 3      NZ  2020-10-29 06:01:41
# 4      ZA  2020-10-29 05:59:51
# 5      RU  2020-10-29 06:01:43
# 6      GM  2020-10-29 06:01:44
# 7      RU  2020-10-29 06:01:45
# 8      CA  2020-10-29 06:01:45
# 9      NZ  2020-10-29 06:01:46

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#               City Country                 Date    Lat     Lng  Max Temp  \
# 0           Bethel      US  2020-10-29 06:01:38  41.37  -73.41     48.00
# 1           Hobart      AU  2020-10-29 05:57:48 -42.88  147.33     62.60
# 2      Meadow Lake      US  2020-10-29 05:56:44  34.80 -106.54     37.40
# 3            Bluff      NZ  2020-10-29 06:01:41 -46.60  168.33     62.01
# 4         Saldanha      ZA  2020-10-29 05:59:51 -33.01   17.94     59.00
# ..             ...     ...                  ...    ...     ...       ...
# 547      Nhulunbuy      AU  2020-10-29 06:08:46 -12.23  136.77     91.40
# 548    Fort Nelson      CA  2020-10-29 06:08:04  58.81 -122.70     30.20
# 549        Kabinda      CD  2020-10-29 06:08:47  -6.13   24.48     71.51
# 550  Moose Factory      CA  2020-10-29 06:08:48  51.26  -80.61     21.20
# 551      Poronaysk      RU  2020-10-29 06:08:48  49.22  143.12     44.62
#
#      Humidity  Cloudiness  Wind Speed
# 0          93           1        2.68
# 1          42          40       13.87
# 2          74           1        3.36
# 3          71          40        3.00
# 4          87          56        3.36
# ..        ...         ...         ...
# 547        49          40       17.22
# 548        86          75        3.36
# 549        93          96        5.68
# 550        73          75       10.29
# 551        73         100       11.14
#
# [552 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import the time module.
import time
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig2.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness (%) "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig3.png")
# Show plot.
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)
# Save the figure.
plt.savefig("weather_data/Fig4.png")
# Show plot.
plt.show()
